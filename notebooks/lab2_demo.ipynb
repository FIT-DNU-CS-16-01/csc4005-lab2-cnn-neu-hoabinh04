# %% [markdown]
# # Lab 2 Demo\nStarter notebook for CNN scratch / transfer learning on NEU-CLS.zip.

# %%
# !python -m src.train --data_dir /path/to/NEU-CLS.zip --project csc4005-lab2-neu-cnn --run_name cnn_small_demo --model_name cnn_small --train_mode scratch --epochs 5 --batch_size 32 --img_size 64 --augment --use_wandb
